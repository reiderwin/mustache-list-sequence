# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import json 
import csv

# %%
#load csv
xrp_data = pd.read_csv("XRPUSD.csv")
xrp_data.head(10)
# Out:
#                                                                                          https://www.CryptoDataDownload.com
# unix       date                symbol  open    high    low     close   Volume XRP                                Volume USD
# 1643846400 2022-02-03 00:00:00 XRP/USD 0.60170 0.60245 0.59710 0.59873 240708.20097614                    144119.2211704443
# 1643760000 2022-02-02 00:00:00 XRP/USD 0.62939 0.63161 0.59437 0.60129 19316016.90244738                 11614527.803272584
# 1643673600 2022-02-01 00:00:00 XRP/USD 0.61723 0.63101 0.61186 0.62794 22921643.07395471                 14393416.551859122
# 1643587200 2022-01-31 00:00:00 XRP/USD 0.60100 0.62476 0.58036 0.61740 42736965.63602803                 26385802.583683703
# 1643500800 2022-01-30 00:00:00 XRP/USD 0.61603 0.62338 0.59753 0.60226 10247638.97689367                  6171743.050223982
# ...
